# %% [markdown]
# # Video example
#
# **This example depends on imageio and imageio-ffmpeg.**
#
# Plays a video as fast as it can. This will be quite a slow playback on localhost. On a remote server it will be even slower.

# %%
import imageio.v3 as iio
import numpy as np
from jupyter_rfb import RemoteFrameBuffer

r = iio.imiter("imageio:cockatoo.mp4")

class VideoPlayer(RemoteFrameBuffer):
    
    def get_frame(self):
        try:
            res = next(r)
        except StopIteration:
            return None
        else:
            v.request_draw()
            return res

        

v = VideoPlayer(max_buffered_frames=3)
v
# Out:
# RFBOutputContext()
# <div class='initial-snapshot-4f87b482a7b1478ab675c72203d90359' style='position:relative;'><img src='data:image/png;base64,...' style='width:500.0px;height:300.0px;' /><div style='position: absolute; top:0; left:0; padding:1px 3px; background: #777; color:#fff; font-size: 90%; font-family:sans-serif; '>initial snapshot</div></div>
# VideoPlayer()
